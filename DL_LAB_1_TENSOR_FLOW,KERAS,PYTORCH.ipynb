# %%
import tensorflow as tf
import numpy as np


#STEP 1: convert data to numpy arrayas
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

#STEP 2: define model uaing inpur layer
model=tf.keras.Sequential([tf.keras.Input(shape=(1,)),tf.keras.layers.Dense(1)])

#step 3: compile the model
model.compile(optimizer='sgd',loss='mean_squared_error')#stostectic gradient disorder

#step 4: train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 62.4532
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 43.3737
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 30.1347
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 20.9482
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 14.5736
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 10.1502
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 7.0806
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4.9505
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3.4723
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 2.4463

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Step 1: Convert data to NumPy arrays
x = np.array([1,2,3,4], dtype=float)
y = np.array([2,4,6,8], dtype=float)

# Step 2: Define model
model = Sequential([
    Dense(1, input_shape=(1,))
])

# Step 3: Compile the model
model.compile(optimizer='sgd', loss='mse')

# Step 4: Train the model
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - loss: 1.6809
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.1674
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.8111
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.5638
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.3922
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.2732
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1906
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1332
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0935
# Epoch 10/10
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#define a simple linear model
model=nn.Linear(1,1)

#loss and optimizer
criterion=nn.MSELoss()
optimizer= optim.SGD(model.parameters(),lr=0.01)

#dummy data
x=torch.tensor([[1.],[2.],[3.],[4.]])
y=torch.tensor([[2.],[4.],[6.],[8.]])


#Training loop
for epoch in range(10):
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterion(outputs,y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1}, Loss :{loss.item()}")
# Out:
# Epoch 1, Loss :12.276952743530273
# Epoch 2, Loss :8.52721881866455
# Epoch 3, Loss :5.9253082275390625
# Epoch 4, Loss :4.119844436645508
# Epoch 5, Loss :2.8670217990875244
# Epoch 6, Loss :1.9976649284362793
# Epoch 7, Loss :1.3943867683410645
# Epoch 8, Loss :0.9757354259490967
# Epoch 9, Loss :0.6851935386657715
# Epoch 10, Loss :0.48354360461235046
